# %%
# %load_ext autoreload
# %autoreload 1

import sys
sys.path.append('./../app/')
# %aimport room
# %aimport agent_delegater
from room import Room
from agent_delegater import BaseAgentDelegater
from prompt_generator import genrate_agent_predict_prompt_with_news_normal
import configs
import datetime
configs.GLOBAL_VERBOSE=False

# %%
room = Room(code='603912',date=datetime.datetime(2023,10,10))
delegater = BaseAgentDelegater()
# delegater._init_agents(cls = BeginnerTrader, size = 10)
delegater._init_stock_info(
    fundamental_info_prompt=room.fundamental_info.to_prompt(),
    tech_info_prompt=room.stock_tech_info.to_prompt(),
    price = room.stock_tech_info.get_price_by_freq_and_index(),
    news_info=room.news_info
)
delegater.set_agents_prompt_func(genrate_agent_predict_prompt_with_news_normal)
# all_orders = delegater.predict_belief()
all_orders =await delegater.apredict_believes()
for item in all_orders:
    print(item)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.81it/s]
# 100%|██████████| 1/1 [00:00<00:00, 11.56it/s]
# **Background**: Chinese Stock trade Market, you should play the Role below and give your action(buy/sell) and your possibility(0 to 100)
# **Aim**: Maximum your profit in short term, depends on your Investment style
# **Role Description**:
#         Senior Trader: You are a senior stock trader, renowned in the trading community for your decades of experience and keen market insights. You are responsible for managing a substantial portfolio, often encompassing multi-million dollar positions across various asset classes.
#             - **Asset Distribution**: Given your vast experience, your portfolio is diverse, ranging from blue-chip stocks, growth stocks, ETFs, commodities, to foreign exchange.
#             - **Investment Philosophy**: Over the years, you've developed a refined trading strategy that melds technical analysis with fundamental research.
#
#             if your investment_aggressiveness is high:
#             - **Approach**: You employ strategies such as high-frequency trading or leveraged investments to amplify returns. You are not averse to dabbling in volatile sectors, emerging markets, or innovative industries like biotech and fintech.
#             - **Objective**: Your primary goal is to beat market benchmarks consistently, aiming for top-tier returns.
#
#             if your investment_aggressiveness is low:
#             - **Approach**: You lean heavily on blue-chip stocks, established companies, and government or corporate bonds. You might also have a significant position in precious metals as a hedge against market volatility.
#             - **Objective**: Your primary aim is wealth preservation with steady growth, targeting returns that outpace inflation while avoiding significant drawdowns.
#
#             if your greediness is high:
#             - **Risk Management**: While you have risk management strategies in place, your focus tends to be on maximizing each trade's profit potential. This might involve holding positions longer than initially planned or leveraging positions to amplify gains.
#             - **Trading Frequency**: You are an active trader, making multiple trades per week, if not per day. Your keen eye is always on the lookout for short-term opportunities or market inefficiencies.
#
#             if your greediness is low:
#             - **Risk Management**: You employ stringent stop-loss orders, diversification strategies, and often consult with risk management tools or teams before making substantial moves.
#             - **Trading Frequency**: You believe in the 'buy and hold' strategy, making infrequent trades, focusing instead on the long-term value proposition of each asset.
#
#             Market Influence: Given the size and volume of your trades, your actions have the potential to cause minor price movements, especially when dealing with small-cap stocks or less liquid markets. This influence demands discretion and strategy in execution to avoid inadvertently moving the market.
#
#
# Role Info:
# Role:Senior Trader
# Investment style: Value Investing
# Risk tolerance (0-10): 1 Ultra Conservative (Primarily in ultra-safe instruments like treasury bills)
# Greediness (0-10): 1 Very slightly greedy
# Investment aggressiveness (0-10): 1 Very Conservative
#
# **Stock Fundamental Info**:Fundamental Information of 佳力图:
# null
#
#
# **Technical indicators Info**:Price Info List sampled by 1 day:
# Price List: [9.32, 9.0, 9.39, 9.13, 8.93, 8.68, 8.61, 8.5, 8.73, 8.58, 8.51, 8.45, 7.93, 7.96, 8.03]
# Volume List: [85506.0, 80568.0, 179067.0, 113359.0, 83313.0, 75645.0, 41781.0, 38256.0, 62983.0, 46714.0, 31768.0, 39931.0, 339153.0, 219737.0, 323271.0]
# The mean price is sampled by frequency 1 day
# The long term period is 30 days, the short term period is 10
# The cross information is No cross
# The Bollinger info:
# bollinger status:normal, no reacing neither up nor down
# bollinger trend: Bollinger Middle Band Trend Down
# MACD Info:
# The macd line is no crossover and the histogram is -0.09
#
# **Related News**:[
#   {
#     "date": "2023-06-09 19:35:25",
#     "title": "周末证券｜加码建设数字经济 算力进入业绩兑现期",
#     "content": "建议关注液冷温控解决方案设备供应商英维克、申菱环境、高澜股份、同飞股份、曙光数创。 潜力股精选英维克002837)高澜股份300499)强瑞技术301128)佳力图603912)CPO：市场需求持续走高 在AI算力高弹性、国产化进程持续推进、下游模块厂商海外业务拓展等的共同催化下，光芯片领域发展前景广阔"
#   },
#   {
#     "date": "2023-06-01 11:43:43",
#     "title": "今日122只个股突破半年线",
#     "content": "70 0.36 5.73 5.76 0.46 000848 承德露露 1.29 0.70 8.57 8.61 0.44 603912 佳力图 2.19 1.63 13.48 13.54 0.44 002249 大洋电机 1.70 0.57 5.35 5.37 0.44"
#   },
#   {
#     "date": "2023-06-10 00:05:29",
#     "title": "加码建设数字经济 算力进入业绩兑现期",
#     "content": "为客户提供液冷相关多工站设备及整线解决方案。若重大资产重组顺利落地，公司液冷业务将实现设备+核心部件一体化布局，有望驶入发展快车道，为公司打造第二成长极。 佳力图（603912） 公司继续专注于数据机房等精密环境控制技术的研发，为数据机房等精密环境控制领域提供节能、控温设备以及相关节能技术服务，产品服务于中国电信、中国联通、中国移动、华为等知名企业"
#   },
#   {
#     "date": "2023-05-25 20:04:57",
#     "title": "公告精选：杭州热电、剑桥科技提示风险；恒盛能源无储能和虚拟电厂业务",
#     "content": "通过深交所交易系统（包括但不限于集中竞价、大宗交易等），以自有资金择机增持公司股份，拟增持股份金额不低于5000万元，不超过1亿元。本次增持不设置价格区间。 佳力图：股东拟减持公司不超3%股份 佳力图603912)5月25日晚间公告，持股16.83%的公司股东安乐工程集团有限公司（简称“安乐集团”）拟通过集中竞价交易方式和大宗交易方式合计减持不超过（含）1160"
#   },
#   {
#     "date": "2023-04-26 15:18:04",
#     "title": "涨停股复盘：5股封单超亿元",
#     "content": "80机械设备003022联泓新科27.315.31281.937699.47电力设备002900哈三联12.402.40486.376030.99医药生物603912佳力图 16.3712.51365.405981.53机械设备603199九华旅游29.391.68176.625190.86社会服务002518科士达47"
#   },
#   {
#     "date": "2023-04-18 16:13:42",
#     "title": "【互动掘金】中科曙光：已为“紫东太初”等多个国内大模型训练提供算力支持",
#     "content": "是影响电堆性能以及寿命的关键之一。金属双极板技术文件的交付为金属极板燃料电池电堆顺利完成开发奠定良好的基础。 佳力图：南京楷德悠云数据中心项目一期已完成土建工程及主要机电设备安装 佳力图603912)在互动平台表示，截至2023年3月31日，“南京楷德悠云数据中心项目（一期）”已完成土建工程及主要机电设备安装"
#   },
#   {
#     "date": "2023-03-22 15:15:04",
#     "title": "涨停股复盘：9股封单超亿元",
#     "content": "54轻工制造002888惠威科技15.6817.96396.866222.70电子600303ST曙光 6.180.28970.175995.64汽车603912佳力图 14.426.58390.265627.55机械设备600605汇通能源11.788.78463.865464.29商贸零售000504南华生物12"
#   },
#   {
#     "date": "2023-03-08 12:18:44",
#     "title": "27只股上午收盘涨停附股)",
#     "content": "76有色金属001366播恩集团14.760.492309.3434085.89农林牧渔002115三维通信6.4714.034684.9230311.40通信603912佳力图 14.162.351955.5627690.74机械设备300252金信诺10.648.902221.9823641.91国防军工600476湘邮科技20"
#   },
#   {
#     "date": "2023-03-08 15:34:04",
#     "title": "涨停股复盘：6股封单超亿元",
#     "content": "%)涨停板封单万股)封单资金万元)行业001337四川黄金13.590.265299.7172023.11有色金属603061金海通 112.291.79502.4456418.99电子603912佳力图 14.162.461073.6315202.56机械设备001366播恩集团14.760.60983.4114515.20农林牧渔600476湘邮科技20"
#   },
#   {
#     "date": "2023-03-08 15:12:17",
#     "title": "A股市场尾盘拉升小幅收跌：成交不足7200亿元 逾3500股收涨",
#     "content": "6亿元，深股通净流入2.46亿元。 6G板块再度爆发 在板块方面，6G板块短暂调整后再度爆发，东数西算、IDC等板块大幅飙涨，佳力图603912)、南兴股份002757)、金信诺300252)、南凌科技300921)等涨停或涨超10%。 石油石化板块领跌两市，中曼石油603619)、海油工程600583)等跌超5%"
#   },
#   {
#     "date": "2023-04-20 21:48:36",
#     "title": "公告精选：宁德时代一季度净利同比增长557.97%；中国移动一季度净利281亿元",
#     "content": "经理、董事会秘书兼财务负责人王莉拟通过集中竞价交易方式减持不超过0.0199%的公司股份；副总经理金衍华拟通过集中竞价交易方式减持不超过0.0191%的公司股份。 佳力图：控股股东拟减持公司不超1%股份 佳力图603912)4月20日晚间公告，公司控股股东楷得投资拟通过集中竞价交易方式，减持不超过386.9万股（占公司总股本的1%）"
#   },
#   {
#     "date": "2022-12-19 12:31:25",
#     "title": "18只股上午收盘涨停附股)",
#     "content": "86食品饮料002172澳洋健康4.4914.072100.959433.27医药生物002330得利斯7.569.331231.859312.79食品饮料603912佳力图 11.315.64748.248462.57机械设备003010若羽臣21.0310.96322.596784.04商贸零售600684珠江股份4"
#   },
#   {
#     "date": "2022-12-20 12:14:28",
#     "title": "24只股上午收盘涨停附股)",
#     "content": "57石油石化002327富安娜8.147.091161.019450.62纺织服饰001209洪兴股份17.7132.07472.258363.48纺织服饰603912佳力图 12.449.27649.478079.42机械设备002186全聚德14.748.83512.127548.65社会服务600847万里股份15"
#   },
#   {
#     "date": "2023-01-04 11:54:16",
#     "title": "57只股上午收盘涨停附股)",
#     "content": ")涨停板封单万股)封单资金万元)行业002235安妮股份8.970.7915488.88138935.26轻工制造000938紫光股份22.410.633449.0477292.98计算机603912佳力图 15.200.824871.7774050.84机械设备000948南天信息25.251.991663.4942003.19计算机001301尚太科技71"
#   },
#   {
#     "date": "2022-12-20 15:33:23",
#     "title": "35只股涨停 最大封单资金3.43亿元",
#     "content": "57电力设备002327富安娜8.1410.29917.967472.16纺织服饰002186全聚德14.7411.10505.577452.05社会服务603912佳力图 12.449.52572.807125.57机械设备600847万里股份15.404.36440.786788.03电力设备002235安妮股份5"
#   },
#   {
#     "date": "2023-01-05 17:23:44",
#     "title": "主力动向：1月5日特大单净流入147.84亿元",
#     "content": "7.36-1.37传媒000419通程控股6.94-9.75-1.31商贸零售002555三七互娱20.184.99-1.29传媒603912佳力图14.47-4.80-1.19机械设备000620新华联3.67-6.62-1.11房地产603000人民网17.40-2.58-1"
#   },
#   {
#     "date": "2023-01-04 15:27:44",
#     "title": "涨停股复盘：11股封单超亿元",
#     "content": "36计算机002696百洋股份8.137.463586.4729157.96农林牧渔000948南天信息25.252.231095.5427662.37计算机603912佳力图 15.200.921572.2623898.33机械设备001301尚太科技71.4350.76297.3721240.80电力设备002279久其软件8"
#   },
#   {
#     "date": "2023-01-03 15:17:22",
#     "title": "116只股涨停 最大封单资金10.87亿元",
#     "content": "39计算机000409云鼎科技7.052.64819.835779.82计算机002343慈文传媒7.1612.08800.985735.00传媒603912佳力图 13.826.48409.105653.82机械设备603881数据港 25.885.20217.575630.79计算机002394联发股份8"
#   },
#   {
#     "date": "2023-04-18 10:48:15",
#     "title": "佳力图：南京楷德悠云数据中心项目一期已完成土建工程及主要机电设备安装",
#     "content": "佳力图603912)在互动平台表示，截至2023年3月31日，“南京楷德悠云数据中心项目（一期）”已完成土建工程及主要机电设备安装，内部变电站施工建设已经完成，但外部电力线路尚在施工建设中，电力线施工过程中需要多个政府部门协调配合，预计将于三季度完成，待外部电力线路施工完成后"
#   },
#   {
#     "date": "2023-01-01 01:18:19",
#     "title": "新冠特效药、信创、供销社 2022年十大爆炒概念都有谁？",
#     "content": "其中，依米康2月18日至3月9日的累积涨幅为147.23%；首都在线于2月18日至2月23日的涨幅也有90.76%。另外概念股佳力图603912.SH)在2月17日至3月1日也有70.27%的涨幅表现，黑牡丹600510.SH)在2月18日至3月10日的累积涨幅为111.01%"
#   }
# ]
#
# You should only respond in JSON format as described below
# Response Format:
# {'Risk tolerance': 0, 'Investment style': 'style', 'Investment aggressiveness': 2, 'decisions': [{'action': 'buy or sell', 'probability': 20, 'percent': 'how much percent you wanna sell/buy. float type,0-100'}]}
# Ensure the response can be parsed by Python json.loads. Don't explain reasons
# [ResponseAgent(risk_tolerance=1, investment_style='Value Investing', investment_aggressiveness='1', decisions=[AgentDecision(action='buy', probability=20, percent=50.0)]), ResponseAgent(risk_tolerance=1, investment_style='Value Investing', investment_aggressiveness='1', decisions=[AgentDecision(action='sell', probability=20, percent=50.0)]), ResponseAgent(risk_tolerance=1, investment_style='Value Investing', investment_aggressiveness='1', decisions=[AgentDecision(action='buy', probability=30, percent=50.0)]), ResponseAgent(risk_tolerance=1, investment_style='Value Investing', investment_aggressiveness='1', decisions=[AgentDecision(action='sell', probability=20, percent=50.0)]), ResponseAgent(risk_tolerance=1, investment_style='Value Investing', investment_aggressiveness='1', decisions=[AgentDecision(action='sell', probability=30, percent=20.0)])]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/zhejianzhang/PrivateProject/quant_agents/notebooks/baseline_with_news.ipynb 单元格 2 line 1
#      <a href='vscode-notebook-cell:/Users/zhejianzhang/PrivateProject/quant_agents/notebooks/baseline_with_news.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> delegater.set_agents_prompt_func(genrate_agent_predict_prompt_with_news_normal)
#      <a href='vscode-notebook-cell:/Users/zhejianzhang/PrivateProject/quant_agents/notebooks/baseline_with_news.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> # all_orders = delegater.predict_belief()
# ---> <a href='vscode-notebook-cell:/Users/zhejianzhang/PrivateProject/quant_agents/notebooks/baseline_with_news.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a> all_orders =await delegater.apredict_believes()
#      <a href='vscode-notebook-cell:/Users/zhejianzhang/PrivateProject/quant_agents/notebooks/baseline_with_news.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> for item in all_orders:
#      <a href='vscode-notebook-cell:/Users/zhejianzhang/PrivateProject/quant_agents/notebooks/baseline_with_news.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a>     print(item)
#
# File ~/PrivateProject/quant_agents/notebooks/./../app/agent_delegater.py:67, in BaseAgentDelegater.apredict_believes(self)
#      65 for agent in self.agents:
#      66     belief = await agent.apredict_believes()
# ---> 67     agent.set_agent_belief(belief)
#      68     orders = agent.plan()
#      69     order_list += orders
#
# File ~/PrivateProject/quant_agents/notebooks/./../app/agents.py:127, in BaseTraderAgent.set_agent_belief(self, agent_response)
#     125 def set_agent_belief(self, agent_response:schemas.ResponseAgent):
#     126     buy_probability, buy_percent, sell_probability, sell_percent = 0,0,0,0
# --> 127     for decision in agent_response.decisions:
#     128         if decision.action.lower() == 'buy':
#     129             buy_probability = decision.probability
#
# AttributeError: 'list' object has no attribute 'decisions'

# %%
from market import StockExchange
# import importlib
# importlib.reload(market)
market = StockExchange()
for item in all_orders:
    market.add_order(item)
market.match_orders()
print('last match order:', market.last_traded_price)
if market.last_traded_price is None:
    print('last trade price:',max([item.price for item in market.buy_orders]))
